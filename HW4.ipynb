# %% [markdown]
# ### HW3 실습2
# 파일명을 입력 받아, 해당 파일을 한 줄씩 읽어 파일의 내
# 용을 모두 대문자로 출력하는 프로그램을 작성하시오.
# 단, 파일이 없는 경우 “파일이 존재하지 않는다" 정도의 아
# 래 메시지를 출력할 것!

# %%
try:
    fr = open("test.txt","r")
    for line in fr:
        if line == '':
            break
        print(line.upper())
    fr.close()
except Exception as e: # except에 조건을 줘서 어떤 에러인지 나타나게 하기
    print("파일이 존재하지 않는다")
# Out:
# WHAT I WANT TO DO IS YOUR HAPPINESS
#
# FILE AND DIRECTORY FUNCTION
#
# SSSSGGGGGG

# %%
import os
if os.path.exists("test.txt"):
    with open("test.txt", "r") as fr :
        for line in fr:
            if line == '':
                break
            print(line.upper())
        fr.close()
else:
    print("파일이 존재하지 않는다")
# Out:
# WHAT I WANT TO DO IS YOUR HAPPINESS
#
# FILE AND DIRECTORY FUNCTION
#
# SSSSGGGGGG

# %% [markdown]
# ### HW3 실습3
# 아래의 실행예시처럼 리눅스 쉘에서 원본파일명
# (src.txt)과 사본파일(dst.txt)을 입력 받아, 복사하는 프로그램을 작성하시오.
#
# ```$ python ex3.py src.txt dst.txt```

# %%
from IPython.display import Image
Image("./HW4_code.png")

# %%
Image("./HW4_console.png")
